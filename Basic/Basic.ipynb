# %%
import os
from simplified_scrapy import SimplifiedDoc, utils

path = 'data/one_run/m'
#read the whole text from 
myList = []
for root, dirs, files in os.walk(path):
    
    for file in files:
        if file.endswith('osm.net.xml'):
            myList.append(os.path.join(root, file))

for file in myList:
    xml = utils.getFileContent(file)
    doc = SimplifiedDoc(xml)
    arg = [ (e['tl'], e['linkIndex'],e['dir'],e['via']) for e in doc.selects('connection')]

    
arg = list(dict.fromkeys(arg))

for file in myList:
    xml = utils.getFileContent(file)
    doc = SimplifiedDoc(xml)
    tl = [ e['id'] for e in doc.selects('tlLogic')]

    


import pandas as pd
data = pd.DataFrame(columns= ["tl","index","dir","via"], index=range(len(arg)))
l = []
for i in range(len(arg)):
    l.append(arg[i][0] )
    if arg[i][0] == tl[0]:
        data.iloc[i,0] = arg[i][0]
        data.iloc[i,3] = arg[i][3]
        data.iloc[i,1] = arg[i][1]
        data.iloc[i,2] = arg[i][2]
        
data.dropna(inplace=True)
data.iloc[:,3] = data.iloc[:,3].str.replace(tl[0],'')
data = data.sort_values(by='index')
data.reset_index(inplace=True,drop=True)
data = data.drop(columns=['tl'])
direction_lane_dict = {}
for i in data.groupby('dir'):
    d = i[0].upper()+'G'
    direction_lane_dict[d] = [int(x) for x in i[1]['index']]
    
for file in myList:
    xml = utils.getFileContent(file)
    doc = SimplifiedDoc(xml)
    arg = [ (e['tl'],e['from'], e['to'],e['fromLane'],e['toLane']) for e in doc.selects('connection')]
            
arg = list(dict.fromkeys(arg))

import pandas as pd
data = pd.DataFrame(columns= ["from","to","froml","tol"], index=range(len(arg)))
for i in range(len(arg)):
    if arg[i][0] == tl[0]:
        data.iloc[i,0] = arg[i][1]
        data.iloc[i,1] = arg[i][2]
        data.iloc[i,2] = arg[i][3]
        data.iloc[i,3] = arg[i][4]
        
data.dropna(inplace=True)
data['from'] = data['from']+'_'+data['froml']
data['to'] = data['to']+'_'+data['tol'] 
l = list(data['from'].unique())
for i in data['to'].unique():
    l.append(i)

node_light_7 = tl[0]
listLanes = set(l)
#rint(listLanes)

direction_list = [k for k in direction_lane_dict]

for file in myList:
    xml = utils.getFileContent(file)
    doc = SimplifiedDoc(xml)
    arg = [ e['state'] for e in doc.selects('phase')]
         
arg = list(dict.fromkeys(arg))
green = []
lenpahse = len(arg[0])
for i in arg: 
    if 'g' in i or 'G' in i:
        green.append(i)
        
phases_names =[]
phases = {}
controlSignal = []



for i in green:
    p = ''
    for j in range(len(i)):
        if i[j]=='G' or i[j]=='g':
            for key in direction_lane_dict:
                if j+1 in direction_lane_dict[key]:
                    if p == '':
                        p = p + key
                    else:
                        p = p + '_' +key

    if p not in phases_names:
        phases[p] = i
        controlSignal.append(i)
        phases_names.append(p)

phases_light_7 = [p for p in phases]
actions= list(phases.values())
numphases = len(phases_light_7)
Durations=[7,3,7,7,7,7,7,3,7]

# %%
import os, sys
import statistics 
if 'SUMO_HOME' in os.environ:
    tools = os.path.join(os.environ['SUMO_HOME'], 'tools')
    sys.path.append(tools)
else:
    sys.exit("please declare environment variable 'SUMO_HOME'")

import traci
from tqdm import tqdm
import random
from time import time
f_memory = open("memorybasics.csv", "w")
f_memory.write('time,action,current_phase,co2,fuel,noise,avg-waiting,avg-travel_time' + "\n")
f_memory.close()
sumoBinary = r"C:\Program Files (x86)\Eclipse\Sumo\bin\sumo-gui"
sumoCmd = [sumoBinary,'-c','data/one_run/m/osm.sumocfg','-n', 'data/one_run/m/osm.net.xml']


time_start = time()
traci.start(sumoCmd)

count=960240
i = 0
while traci.simulation.getTime() <= count:
    
    laneQueueTracker=[]
    laneNumVehiclesTracker=[]
    laneWaitingTracker=[]
    laneNoiseTracker=[]
    co2Tracker=[]
    fuelTracker=[]
    traveltimeTracker=[]
    current_time = traci.simulation.getTime()
    
    action= i%9

    duration= Durations[action]    
    traci.trafficlight.setRedYellowGreenState(node_light_7, actions[action])
    while traci.simulation.getTime() < current_time + duration:
        traci.simulationStep()
        continue

    Yellow = ''
    for j in range(len(phases_light_7[0])):
        Yellow = Yellow+"y"
        
    for j in range(3):
        timestamp = traci.simulation.getTime()
        traci.trafficlight.setRedYellowGreenState(node_light_7, Yellow)
        traci.simulationStep()
        
    for lane in listLanes:
        laneQueueTracker.append(traci.lane.getLastStepHaltingNumber(lane))

   
    for lane in listLanes:
        laneNumVehiclesTracker.append(traci.lane.getLastStepVehicleNumber(lane))

  
    for lane in listLanes:
        laneWaitingTracker.append(traci.lane.getWaitingTime(str(lane)) / 60)

        
    for lane in listLanes:
        laneNoiseTracker.append((traci.lane.getNoiseEmission(str(lane))))

    
    for lane in listLanes:
        co2Tracker.append(traci.lane.getCOEmission(lane))
        fuelTracker.append(traci.lane.getFuelConsumption(lane))
        traveltimeTracker.append(traci.lane.getTraveltime(lane))
     
    i = i + 1   

    f_memory = open("memorybasics.csv", "a")
    memory_str = '%d,%d,%s,%f,%f' \
                     ',%f,%f,%f' \
                     % (traci.simulation.getTime(), action,
                        action, sum(co2Tracker),sum(fuelTracker), sum(laneNoiseTracker),statistics.mean(laneWaitingTracker),statistics.mean(traveltimeTracker))
    
    f_memory.write(memory_str + "\n")
    f_memory.close()
    
    print("laneQueue: ", sum(laneQueueTracker),"laneNumVehicles:",sum(laneNumVehiclesTracker),"laneWaiting:",sum(laneWaitingTracker),"noise:",sum(laneNoiseTracker),"co2:",sum(co2Tracker),"fuel:",sum(fuelTracker),"TravelTime:",statistics.mean(traveltimeTracker))
    
    
    
time_end = time()
print ("traci time elapsed: {}".format(time_end-time_start))
traci.close(True)
# Out:
# ---------------------------------------------------------------------------
# FatalTraCIError                           Traceback (most recent call last)
# Cell In[2], line 51
#      49     timestamp = traci.simulation.getTime()
#      50     traci.trafficlight.setRedYellowGreenState(node_light_7, Yellow)
# ---> 51     traci.simulationStep()
#      53 for lane in listLanes:
#      54     laneQueueTracker.append(traci.lane.getLastStepHaltingNumber(lane))
#
# File C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:199, in simulationStep(step)
#     192 def simulationStep(step=0):
#     193     """simulationStep(float) -> list
#     194     Make a simulation step and simulate up to the given second in sim time.
#     195     If the given value is 0 or absent, exactly one step is performed.
#     196     Values smaller than or equal to the current sim time result in no action.
#     197     It returns the subscription results for the current step in a list.
#     198     """
# --> 199     return connection.check().simulationStep(step)
#
# File C:\Program Files (x86)\Eclipse\Sumo\tools\traci\connection.py:366, in Connection.simulationStep(self, step)
#     364 if type(step) is int and step >= 1000:
#     365     warnings.warn("API change now handles step as floating point seconds", stacklevel=2)
# --> 366 result = self._sendCmd(tc.CMD_SIMSTEP, None, None, "D", step)
#     367 for subscriptionResults in self._subscriptionMapping.values():
#     368     subscriptionResults.reset()
#
# File C:\Program Files (x86)\Eclipse\Sumo\tools\traci\connection.py:228, in Connection._sendCmd(self, cmdID, varID, objID, format, *values)
#     226     self._string += struct.pack("!i", len(objID)) + objID.encode("latin1")
#     227 self._string += packed
# --> 228 return self._sendExact()
#
# File C:\Program Files (x86)\Eclipse\Sumo\tools\traci\connection.py:137, in Connection._sendExact(self)
#     135     self._socket.close()
#     136     self._socket = None
# --> 137     raise FatalTraCIError("connection closed by SUMO")
#     138 for command in self._queue:
#     139     prefix = result.read("!BBB")
#
# FatalTraCIError: connection closed by SUMO
